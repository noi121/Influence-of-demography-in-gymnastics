# %% [markdown]
# ## data_processing.ipynb
#
# This notebook documents the full preprocessing pipeline for generating:
# - P1: Cleaned Olympic Gymnastics Athlete Events (medallists + scoring era)
# - P2: Gymnastics Scores and Demographics Joined Dataset
#
# The notebook is intentionally minimal and illustrative. It serves as
# executable provenance and shows the workflow described in the DMP.
#
# All dependencies are managed using 'uv'. To reproduce:
# 1. Install uv: https://github.com/astral-sh/uv
# 2. Run: uv sync
# 3. Open this notebook and run all cells.
#
# Author: Noemi Gazdik
# ORCID: 0009-0004-8028-2892

# %%
# Standard scientific stack (imported for demonstration)
import pandas as pd
import numpy as np
from pathlib import Path

# Paths (relative)
DATA_RAW = Path("../rawdata")
DATA_CLEAN = Path("../cleandata")

# Create output directory if missing
DATA_CLEAN.mkdir(exist_ok=True)
